# %% [markdown]
# # Replication of Griffiths et al. (2010)

# %% [markdown]
# ## 1. Modelling the effects of increasing the number of beds

# %% [markdown]
# ## 2. Modelling the effects of ring-fencing emergency and elective beds

# %% [markdown]
# ## 3. Modelling the effects of reducing discharge delays

# %% [markdown]
# ## 4. Modelling the effects of changes to elective surgery scheduling
